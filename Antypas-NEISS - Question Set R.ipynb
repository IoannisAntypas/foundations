# %% [markdown]
# # Exercise: NEISS, Question Set R
#
# #### Summary
#
# The [National Electronic Injury Surveillance System](https://www.cpsc.gov/Safety-Education/Safety-Guides/General-Information/National-Electronic-Injury-Surveillance-System-NEISS) is a data product produced by the US Consumer Product Safety Commission. It tracks emergency room injuries related to consumer products (e.g., "a door fell on me!").
#
# #### Files
#
# - **nss15.tsv**: injury data (one injury per row)
# - **2017NEISSCodingManualCPSConlyNontrauma.pdf**: column definitions and explanations
# - **2015 Neiss data highlights.pdf**: a partial summary of the data
# - **2017ComparabilityTable.pdf**: product code definitions
# - **categories-cleaned.txt**: product code definitions in CSV format (great for joining!)
#
# #### Source
#
# https://www.cpsc.gov/Safety-Education/Safety-Guides/General-Information/National-Electronic-Injury-Surveillance-System-NEISS
#
# #### Skills
#
# - Using codebooks
# - Reading tab-separated files
# - Ignoring bad lines
# - Replacing LOTS of values
# - Merging dataframes
# - Using numpy/`np.nan`
# - Padding strings
# - String search using regular expressions

# %% [markdown]
# # Read in `nss15.tsv`
#
# Some of the lines just **aren't formatted correctly**. Maybe we can avoid those?

# %%
import pandas as pd

# %%
df = pd.read_csv("nss15.tsv", sep="\t", error_bad_lines=False, na_values=["Unknown", "???", 'not recorded', 'not_recorded'])
# Out:
# b'Skipping line 10822: expected 19 fields, saw 20\n'
# b'Skipping line 48623: expected 19 fields, saw 20\nSkipping line 62534: expected 19 fields, saw 20\n'
# b'Skipping line 103739: expected 19 fields, saw 20\n'
# b'Skipping line 135495: expected 19 fields, saw 20\nSkipping line 151678: expected 19 fields, saw 20\n'
# b'Skipping line 237135: expected 19 fields, saw 20\nSkipping line 240597: expected 19 fields, saw 20\n'
# b'Skipping line 274270: expected 19 fields, saw 20\nSkipping line 277461: expected 19 fields, saw 20\n'

# %% [markdown]
# ### Check that your dataframe has 357727 rows and 19 columns.

# %%
df.shape
# Out:
# (357727, 19)

# %% [markdown]
# ### List the columns and their data types

# %%
df.dtypes
# Out:
# CPSC Case #      int64
# trmt_date       object
# psu              int64
# weight         float64
# stratum         object
# age              int64
# sex              int64
# race             int64
# race_other      object
# diag             int64
# diag_other      object
# body_part        int64
# disposition      int64
# location         int64
# fmv              int64
# prod1            int64
# prod2          float64
# narr1           object
# narr2           object
# dtype: object

# %% [markdown]
# ### What does each column mean?

# %%
#diag is diagnosis that has an integer that indicates what the patient has
#body part is an integer that indicates the specific body part
#weight measures the statistical weight, its not defined what exactly
#location of where the accident was treated. Probably
#FMV Fire related stuff

# %% [markdown]
# # Cleaning up a column
#
# Take a look at the **body part** column. How many rows of each body part are there?

# %%
df['body_part'].value_counts()
# Out:
# 75    58677
# 76    30992
# 79    30579
# 92    30463
# 37    20077
# 31    19518
# 35    18957
# 82    17077
# 83    15890
# 30    14822
# 33    13655
# 36    12771
# 34    11565
# 32     8888
# 85     8615
# 88     7336
# 93     7299
# 89     6145
# 77     4661
# 94     4404
# 81     4174
# 80     4016
# 0      3344
# 87     2079
# 38     1699
# 84       24
# Name: body_part, dtype: int64

# %% [markdown]
# ## Replace the numbers with the appropriate words they stand for.
#
# Those numbers are terrible - codes are fine for storage but not really for reading. **Replace the numbers with the  words they stand for.**
#
# Refer to pages 11-12 of the column definitions file, or... hey, I typed it in below!
#
# - Tip: If I've already talked about how to replace values, maybe there's a really easy way to replace a lot at once? Maybe I'll tell you if you ask me?

# %%
# 0:  'internal'
# 30: 'shoulder'
# 31: 'upper trunk'
# 32: 'elbow'
# 33: 'lower arm'
# 34: 'wrist'
# 35: 'knee'
# 36: 'lower leg'
# 37: 'ankle'
# 38: 'pubic region'
# 75: 'head'
# 76: 'face'
# 77: 'eyeball'
# 79: 'lower trunk'
# 80: 'upper arm'
# 81: 'upper leg'
# 82: 'hand'
# 83: 'foot'
# 84: '25-50% of body'
# 85: 'all parts of body'
# 87: 'not recorded'
# 88: 'mouth'
# 89: 'neck'
# 92: 'finger'
# 93: 'toe'
# 94: 'ear'

# %%
replacements = {
0:  'internal',
30: 'shoulder',
31: 'upper trunk',
32: 'elbow',
33: 'lower arm',
34: 'wrist',
35: 'knee',
36: 'lower leg',
37: 'ankle',
38: 'pubic region',
75: 'head',
76: 'face',
77: 'eyeball',
79: 'lower trunk',
80: 'upper arm',
81: 'upper leg',
82: 'hand',
83: 'foot',
84: '25-50% of body',
85: 'all parts of body',
87: 'not recorded',
88: 'mouth',
89: 'neck',
92: 'finger',
93: 'toe',
94: 'ear', }

df.body_part.replace(replacements, inplace=True)

# %%
df['body_part']
# Out:
# 0                 lower arm
# 1                     wrist
# 2                       ear
# 3                      knee
# 4                      head
# 5                      face
# 6                 lower arm
# 7                  shoulder
# 8                      face
# 9               lower trunk
# 10                     hand
# 11                lower leg
# 12                    mouth
# 13                     head
# 14                      toe
# 15                     hand
# 16                     foot
# 17                   finger
# 18              lower trunk
# 19                     face
# 20              lower trunk
# 21                     knee
# 22                     head
# 23                    wrist
# 24                     face
# 25                     head
# 26                      toe
# 27                      ear
# 28                     head
# 29              upper trunk
#                 ...
# 357697                mouth
# 357698                  ear
# 357699                 foot
# 357700                mouth
# 357701          lower trunk
# 357702                ankle
# 357703            upper arm
# 357704                 head
# 357705                 face
# 357706                  ear
# 357707          lower trunk
# 357708               finger
# 357709            lower arm
# 357710                ankle
# 357711                 head
# 357712            lower leg
# 357713                  ear
# 357714             shoulder
# 357715                elbow
# 357716    all parts of body
# 357717               finger
# 357718          lower trunk
# 357719                  ear
# 357720                 head
# 357721                 head
# 357722                 face
# 357723    all parts of body
# 357724          lower trunk
# 357725                 hand
# 357726                wrist
# Name: body_part, Length: 357727, dtype: object

# %% [markdown]
# ## Confirm you have 58677 head, 30992 face, and 30579 lower trunk.
#
# Isn't this much nicer?

# %%
df['body_part'].value_counts().head(3)
# Out:
# head           58677
# face           30992
# lower trunk    30579
# Name: body_part, dtype: int64

# %% [markdown]
# ## Graph the number of each body part, but don’t included the “Not Recorded” records

# %%
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df[df.body_part != 'not recorded'].body_part.value_counts(ascending=True).plot(kind= 'barh')

# %% [markdown]
# ## "Not Recorded" seems silly - change it to be `NaN` instead
#
# Don't use `na_values` for this.

# %%
import numpy as np

# %%
np.nan
# Out:
# nan

# %%
df.body_part.replace('not recorded', 'NaN', inplace=True)

# %%
df.body_part.replace('NaN', np.nan, inplace=True)

# %%
df.body_part.value_counts()
# Out:
# head                 58677
# face                 30992
# lower trunk          30579
# finger               30463
# ankle                20077
# upper trunk          19518
# knee                 18957
# hand                 17077
# foot                 15890
# shoulder             14822
# lower arm            13655
# lower leg            12771
# wrist                11565
# elbow                 8888
# all parts of body     8615
# mouth                 7336
# toe                   7299
# neck                  6145
# eyeball               4661
# ear                   4404
# upper leg             4174
# upper arm             4016
# internal              3344
# pubic region          1699
# 25-50% of body          24
# Name: body_part, dtype: int64

# %% [markdown]
# ## Graph the count of each body part, but don’t included the “Not Recorded” records
#
# Yes, again! The code you use should be different this time.

# %%
df.body_part.value_counts()
# Out:
# head                 58677
# face                 30992
# lower trunk          30579
# finger               30463
# ankle                20077
# upper trunk          19518
# knee                 18957
# hand                 17077
# foot                 15890
# shoulder             14822
# lower arm            13655
# lower leg            12771
# wrist                11565
# elbow                 8888
# all parts of body     8615
# mouth                 7336
# toe                   7299
# neck                  6145
# eyeball               4661
# ear                   4404
# upper leg             4174
# upper arm             4016
# internal              3344
# pubic region          1699
# 25-50% of body          24
# Name: body_part, dtype: int64

# %% [markdown]
# ## For each body part, get the average age of the person who injured that part
#
# Sort from youngest to oldest

# %%
df.groupby('body_part')['age'].mean().sort_values()
# Out:
# body_part
# pubic region         19.985874
# ear                  24.248183
# ankle                28.477512
# wrist                30.697968
# lower arm            32.357598
# foot                 32.578666
# knee                 34.106451
# toe                  34.988766
# hand                 35.811208
# finger               35.978170
# elbow                36.592934
# eyeball              36.669599
# neck                 38.354109
# shoulder             39.266901
# lower leg            44.255814
# 25-50% of body       44.333333
# upper leg            45.934835
# upper trunk          46.587663
# upper arm            46.655129
# face                 47.749193
# lower trunk          49.667844
# mouth                51.241957
# head                 59.512637
# internal             62.912978
# all parts of body    63.406268
# Name: age, dtype: float64

# %% [markdown]
# ## Wait, "not recorded" seems really really really really old!
#
# How can the average age be like 80???? Read page 6 of the documentation. Fix the issue however you think is best, but explain what you're doing. **It would be nice to talk about this in class if you'd write it on the board!**
#
# ### Tech tip you might find useful
#
# If you want to replace a column based on a condition, pandas will probably yell at you. You get to learn this new thing called `loc` now!
#
# ```
# df.loc[df.country == 'Angola', "continent"] = "Africa"
# ```
#
# This updates the `continent` column to be `Africa` for every row where `country == 'Angola'`. You CANNOT do the following, which is probably what you've wanted to do:
#
# ```
# df[df.country == 'Angola']['continent'] = 'Africa'
# ```
#
# And now you know.

# %%
df.head(1)
# Out:
#    CPSC Case #   trmt_date  psu   weight stratum  age  sex  race race_other  \
# 0    150733174  07/11/2015   38  15.7762       V    5    1     0        NaN
#
#    diag diag_other  body_part  disposition  location  fmv  prod1  prod2  \
# 0    57        NaN  lower arm            1         9    0   1267    NaN
#
#                                                narr1 narr2
# 0  5 YR OLD MALE PLAYING SOCCER BLOCKING BALL AND...  X IT

# %%
import re

# %% [markdown]
# # Finding injuries

# %% [markdown]
# ## How many people were injured by "Musical instruments, electric or battery operated?"
#
# Try to do what you think would work, then see... it doesn't work. There are all kinds of reasons why it wouldn't work. Keep reading once it doesn't work for you.
#
# - Tip: `prod1` and `prod2` are the product fields
# - Tip: You can use the codebook or `cleaned-categories.txt`

# %%
df[df.prod1.isin(["565"])].count()
# Out:
# CPSC Case #    14
# trmt_date      14
# psu            14
# weight         14
# stratum        14
# age            14
# sex            14
# race           14
# race_other      0
# diag           14
# diag_other      3
# body_part      14
# disposition    14
# location       14
# fmv            14
# prod1          14
# prod2           1
# narr1          14
# narr2           9
# dtype: int64

# %% [markdown]
# ### Did something go wrong when you read in your data?
#
# Maybe it's one of those problems like we had with `008382` in the homework, where when we read in the file it got rid of the leading zeroes? Try to read the file in again and fix that.
#
# Try to get all of the "Musical instruments, electric or battery operated" injurie again. It still won't work. Keep reading.

# %% [markdown]
# ### Looks the data export is bad!
#
# They turned `0565` into `565` when they exported it or something (so irresponsible!), and it's up to us to fix it. Pad the `prod1` and `prod2` columns to be the proper length. If you didn't actually do the task above it's going to be more difficult.

# %% [markdown]
# ## How many people were injured by musical instruments, total?
#
# Include normal musical instruments, electric musical instruments and toy musical instruments.
#
# - Tip: You can use the codebook or `cleaned-categories.txt`
# - Tip: Answer this in one line **without** using `and` or `&`.

# %%
df[df.prod1.isin(["565", "566", "1344", "1734"])].count()
# Out:
# CPSC Case #    228
# trmt_date      228
# psu            228
# weight         228
# stratum        228
# age            228
# sex            228
# race           228
# race_other       9
# diag           228
# diag_other      44
# body_part      228
# disposition    228
# location       228
# fmv            228
# prod1          228
# prod2           16
# narr1          228
# narr2          162
# dtype: int64

# %%
#0565  566 1344 1734

# %% [markdown]
# ## Out of those three, which is the most popular reason for admission?

# %%
#leading zeroes if it was not a string column yet
df.prod1.astype(str).str.pad(4, fillchar='0')
# Out:
# 0         1267
# 1         1439
# 2         3274
# 3         0611
# 4         1893
# 5         1715
# 6         1138
# 7         5040
# 8         1807
# 9         4057
# 10        1894
# 11        1267
# 12        3274
# 13        1807
# 14        4057
# 15        0894
# 16        1817
# 17        0380
# 18        4014
# 19        0474
# 20        0676
# 21        5036
# 22        1239
# 23        1329
# 24        0611
# 25        0679
# 26        1884
# 27        3274
# 28        4076
# 29        1211
#           ...
# 357697    5017
# 357698    1616
# 357699    1426
# 357700    4076
# 357701    4014
# 357702    1233
# 357703    1807
# 357704    3262
# 357705    3286
# 357706    1871
# 357707    0676
# 357708    0464
# 357709    0836
# 357710    1205
# 357711    4076
# 357712    1807
# 357713    1936
# 357714    1842
# 357715    3216
# 357716    1913
# 357717    1616
# 357718    1522
# 357719    1616
# 357720    1807
# 357721    1301
# 357722    1864
# 357723    1931
# 357724    3250
# 357725    0464
# 357726    3273
# Name: prod1, Length: 357727, dtype: object

# %%
musical = ["0565", "0566", "1344", "1734"]

# %% [markdown]
# ## What parts of the body are injured by musical instruments most often?

# %%
df[df.prod1.isin(["565", "566", "1344", "1734"])]['body_part'].value_counts()  #.groupby(df.body_part).count() DONT DO THIS
# Out:
# face                 32
# head                 30
# finger               23
# upper trunk          19
# mouth                18
# lower trunk          16
# shoulder             13
# wrist                12
# toe                  10
# foot                  9
# all parts of body     6
# knee                  6
# lower arm             6
# eyeball               5
# neck                  5
# hand                  4
# elbow                 4
# lower leg             3
# ear                   3
# ankle                 2
# upper arm             1
# internal              1
# Name: body_part, dtype: int64

# %% [markdown]
# # Adding categories

# %% [markdown]
# ## Read in `categories-cleaned.txt`

# %%
import re

# %%
df
# Out:
#         CPSC Case #   trmt_date  psu   weight stratum  
# 357711    150643117  05/31/2015   90   5.6748       C  201    1     1
# 357712    150607827  05/27/2015   32   5.6748       C  218    1     1
# 357713    150600190  05/28/2015   73  80.8381       S    5    1     0
# 357714    150648619  06/17/2015   95  15.7762       V   52    2     1
# 357715    150640832  06/08/2015   67  15.7762       V    8    2     0
# 357716    150633445  05/31/2015   50  74.8813       L  220    2     0
# 357717    150633526  04/04/2015   14  49.2646       M   51    2     0
# 357718    150628863  06/08/2015   95  15.7762       V   30    2     1
# 357719    150607637  05/22/2015   32   5.6748       C  215    2     2
# 357720    150747209  07/24/2015   73  83.2157       S   14    2     0
# 357721    150747217  07/24/2015   73  83.2157       S    2    1     0
# 357722    150739278  05/31/2015   23  15.0591       V    7    1     0
# 357723    150733393  07/11/2015   18   5.6748       C    3    2     2
# 357724    150819286  07/24/2015   21  15.7762       V   38    1     0
# 357725    150823002  08/08/2015   78  97.9239       M   38    2     1
# 357726    150723074  06/20/2015   54  49.2646       M    5    2     1
#
#        race_other  diag        diag_other          body_part  disposition  \
# 0             NaN    57               NaN          lower arm            1
# 1             NaN    57               NaN              wrist            1
# 2             NaN    71    OTITIS EXTERNA                ear            1
# 3             NaN    71              PAIN               knee            1
# 4        HISPANIC    62               NaN               head            1
# 5             NaN    71  DOG SCRATCH/BITE               face            1
# 6             NaN    51               NaN          lower arm            4
# 7             NaN    57               NaN           shoulder            1
# 8             NaN    59               NaN               face            1
# 9             NaN    53               NaN        lower trunk            1
# 10            NaN    59               NaN               hand            1
# 11            NaN    57               NaN          lower leg            1
# 12            NaN    60               NaN              mouth            1
# 13            NaN    62               NaN               head            1
# 14            NaN    53               NaN                toe            1
# 15            NaN    59               NaN               hand            1
# 16            NaN    59               NaN               foot            1
# 17            NaN    57               NaN             finger            1
# 18            NaN    64               NaN        lower trunk            1
# 19            NaN    59               NaN               face            1
# 20            NaN    64               NaN        lower trunk            1
# 21            NaN    59               NaN               knee            4
# 22            NaN    58               NaN               head            1
# 23            NaN    57               NaN              wrist            1
# 24            NaN    58               NaN               face            1
# 25            NaN    58               NaN               head            1
# 26            NaN    64               NaN                toe            1
# 27            NaN    71            OTITIS                ear            1
# 28            NaN    62               NaN               head            4
# 29            NaN    64               NaN        upper trunk            1
# ...           ...   ...               ...                ...          ...
# 357697        NaN    60               NaN              mouth            1
# 357698        NaN    71              PAIN                ear            1
# 357699        NaN    53               NaN               foot            1
# 357700        NaN    59               NaN              mouth            1
# 357701        NaN    64               NaN        lower trunk            1
# 357702        NaN    64               NaN              ankle            1
# 357703        NaN    57               NaN          upper arm            4
# 357704        NaN    59               NaN               head            1
# 357705        NaN    57               NaN               face            2
# 357706        NaN    59               NaN                ear            1
# 357707        NaN    57               NaN        lower trunk            5
# 357708        NaN    59               NaN             finger            1
# 357709   HISPANIC    59               NaN          lower arm            1
# 357710        NaN    64               NaN              ankle            1
# 357711        NaN    62               NaN               head            1
# 357712        NaN    71              LIMP          lower leg            1
# 357713        NaN    56               NaN                ear            1
# 357714        NaN    64               NaN           shoulder            1
# 357715        NaN    64               NaN              elbow            1
# 357716        NaN    68               NaN  all parts of body            1
# 357717        NaN    56               NaN             finger            1
# 357718        NaN    64               NaN        lower trunk            1
# 357719        NaN    59               NaN                ear            1
# 357720        NaN    62               NaN               head            1
# 357721        NaN    62               NaN               head            1
# 357722        NaN    59               NaN               face            1
# 357723        NaN    68               NaN  all parts of body            1
# 357724        NaN    71              PAIN        lower trunk            1
# 357725        NaN    59               NaN               hand            1
# 357726        NaN    57               NaN              wrist            1
#
#         location  fmv  prod1   prod2  \
# 0              9    0   1267     NaN
# 1              1    0   1439  4057.0
# 2              0    0   3274     NaN
# 3              0    0    611     NaN
# 4              0    0   1893  1807.0
# 5              1    0   1715     NaN
# 6              9    3   1138     NaN
# 7              0    0   5040     NaN
# 8              1    0   1807     NaN
# 9              5    0   4057  1807.0
# 10             1    0   1894     NaN
# 11             9    0   1267     NaN
# 12             0    0   3274  1284.0
# 13             1    0   1807     NaN
# 14             1    0   4057     NaN
# 15             0    0    894     NaN
# 16             1    0   1817     NaN
# 17             1    0    380     NaN
# 18             1    0   4014     NaN
# 19             1    0    474     NaN
# 20             0    0    676     NaN
# 21             1    0   5036     NaN
# 22             0    0   1239     NaN
# 23             0    0   1329     NaN
# 24             1    0    611     NaN
# 25             0    0    679  1807.0
# 26             0    0   1884     NaN
# 27             0    0   3274     NaN
# 28             1    0   4076     NaN
# 29             0    0   1211     NaN
# ...          ...  ...    ...     ...
# 357697         9    0   5017     NaN
# 357698         0    0   1616     NaN
# 357699         1    0   1426     NaN
# 357700         1    0   4076     NaN
# 357701         1    0   4014     NaN
# 357702         9    0   1233     NaN
# 357703         1    0   1807     NaN
# 357704         1    0   3262     NaN
# 357705         0    0   3286     NaN
# 357706         1    0   1871     NaN
# 357707         1    0    676  1884.0
# 357708         1    0    464     NaN
# 357709         1    0    836     NaN
# 357710         9    0   1205     NaN
# 357711         1    0   4076  1807.0
# 357712         1    0   1807     NaN
# 357713         0    0   1936     NaN
# 357714         1    0   1842     NaN
# 357715         0    0   3216     NaN
# 357716         0    0   1913     NaN
# 357717         1    0   1616     NaN
# 357718         1    0   1522     NaN
# 357719         0    0   1616     NaN
# 357720         5    0   1807     NaN
# 357721         1    0   1301     NaN
# 357722         1    0   1864     NaN
# 357723         0    0   1931     NaN
# 357724         0    0   3250     NaN
# 357725         1    0    464     NaN
# 357726         9    0   3273     NaN
#
#                                                     narr1  \
# 0       5 YR OLD MALE PLAYING SOCCER BLOCKING BALL AND...
# 1       L WRIST FX(?)/36YOWM 2 WKS AGO@G-FRIENDS HM,MO...
# 2       20 YO F C/O EAR PAIN 1 DAY SAS WAS SWIMMING YE...
# 3       61YOM W/KNEE PAIN S/P FALLING IN SHOWER 2 DAYS...
# 4       88YOF PAIN TO HEAD WHEN FALL TO FLOOR WHEN WAL...
# 5       16 MOF AT HOME PULLED FAMILY DOG-HUSKIES COLLA...
# 6       25 YOM WAS CAMPING WHEN FRIEND THREW A PRESSUR...
# 7       53 YOM BIKE WRECK SUNDAY PAIN CHEST SHOULDER &...
# 8               98 Y/O M FELL IN FLOOR AND LACERATED FACE
# 9       48 YO F, C/O RT FLANK PAIN 6 DAYS S/P FALL WAS...
# 10      20 YOM DX HAND LACERATION - S/P PT PUNCHED A W...
# 11      L DISTAL FIB FX/20YOWF WHILE PLAYING SOCCER AT...
# 12      DX LOSS TEETH D/T TRAUME: 11YOM LOOSE LOWER R ...
# 13      CHI,LEFT WRIST SPRAIN.26YOF SLIPPED AND FELL O...
# 14         33 YOM SMASHED FOOT INTO COFFEE TABLE LAST PM.
# 15                         36 YOM CUT HAND WITH A HACKSAW
# 16      65 YO WF CUT FOOT WHEN BARE FOOTED ON PORCH AT...
# 17      2YOM INJURED FINGER BY PUTTING IT IN A HOUSE F...
# 18      LUMBAR STRIAN. 69 YOF STRAINED HER LOWER BACK ...
# 19              4 M/.O F   BROTHER  DROPPED  CUP  ON FACE
# 20      LUMBAR STR.  47YOF STRAINED LOWER BACK RIPPING...
# 21      16 YOM TRIED TO DO A WHEELIE ON HIS DIRT BIKE ...
# 22      31 YOM WAS THROWN FROM A HORSE INTO A TREE AND...
# 23       7YOM SUST WRIST FX WHEN HE FELL OFF HIS SCOOTER*
# 24      27YOF H'TOMA F'HEAD - SYNCOPE, FELL GETTING OU...
# 25      9 MO F AT 11:30AM TODAY FELL APPROX 2 FT FT BA...
# 26      27 YO F C/O LT 5TH TOE PAIN REPORTS STUBBING T...
# 27      39YOM DOING ALOT OF SWIMMING AND NOW EARS HURT...
# 28      7 MONTH M WITH CHI HIT HEAD, FELL FROM BED - A...
# 29      14YOM PAIN TO BACK AND HEAD WHEN PLAYING FOOTB...
# ...                                                   ...
# 357697  DX DENTAL INJ 4YOM PATIENT WAS STRUCK IN HIS M...
# 357698  33 YOF INJURED EAR WEARING EARRINGS 2 DAYS AGO...
# 357699  51YF ACC STRUCK FOOT C AN AXE HANDLE WHILE HEL...
# 357700     3YOM JUMPED OFF OF BED HIT MOUTH HAS A LIP LAC
# 357701  21 YOF C/O LOW BACK PAIN AFTER HELPING MOVE HE...
# 357702  12YOF JUMPING ON A TRAMPOLINE AT *** AND STRAI...
# 357703  85YOF FELL TO HER BATHROOM FLOOR AND FRACTURED...
# 357704         4 YOM FELL OFF POOL LADDER  DX:  SCALP LAC
# 357705  5 YOF 4 WHEELERS ACCIDENT, EJECTED D X:  MULTI...
# 357706  5 YOF MOTHER STATES CHILD RAN INTO A FENCE AT ...
# 357707                85YOF FX HIP- TRIPPED RUG, HIT WALL
# 357708  12YF ACC CUT FINGER ON A KNIFE CUTTING ICECREA...
# 357709          27 YOM LAC TO ARM WHEN USING A BOX CUTTER
# 357710    15 YO MALE PLAYING BASKETBALL.  DX ANKLE SPRAIN
# 357711  1MOM-PT & 5YOLD SIBLING WERE LAYING ON THE BED...
# 357712  18 MOM PLAYING WITH BROTHER THIS A.M. AND FELL...
# 357713                  5YOM PUT A BB IN RIGHT EAR FB EAR
# 357714  RT SHOULDER STR.  52YOF FELL GOING DOWN A FLIG...
# 357715  DX ELBOW STRAIN R: 8YOF FELL YTDY W ROLLER SKA...
# 357716  20 MOF TOXIC INGESTION, MOM REPORTS WITNESSING...
# 357717                  51YOF F'BDY- RING STUCK ON FINGER
# 357718  LUMBAR STRAIN. 30 YOF STRAINED HER LOWER BACK ...
# 357719  15 MOF R EARRING WAS PULLED OUT OF EAR RESULTI...
# 357720  14YOF AT THE HOSPITAL WAS WITNESSING HER SISTE...
# 357721  2YOM FELL OFF HIS TRICYCLE TO THE DRIVEWAY ONT...
# 357722  7 YO MALE HIT CORNER OF COUNTER WHILE PLAYING....
# 357723     3 YOF INGESTED 60 VITAMIN ***.  DX: INGESTION.
# 357724  38YM C/O WORSENING LBP THAT STARTED WHILE LIFT...
# 357725  38 YOF INJURED HAND, CUT WITH BREAD KNIFE AT H...
# 357726  5YOF ON A PLAYGROUND & FELL OFF PLAY STRUCTURE...
#
#                                                     narr2
# 0                                                    X IT
# 1       AN OBJECT&TWISTED WRIST TRYING TO CONTOL MOWER...
# 2       T TRIED TO USE ***S TO REMOVE WAX MADE IT WORS...
# 3                                                     NaN
# 4                DOOR AND FELL.DENIES LOC. DX HEAD INJURY
# 5       ND SCRAPING TEETH ON PTS FACE, NOT A TRUE BITE...
# 6       WHICH FLASHED. FD NS. DX:  BURNS L UPPER & LOW...
# 7                                                     NaN
# 8                                                     NaN
# 9       ABLE WHICH HIT THE FLOOR STRIKING RT FLANK DX ...
# 10                                                    NaN
# 11                       LE CAUSING INJURY TO DISTAL FIB.
# 12                      M OF POOL KNOCKING HIS TOOTH LOSE
# 13                                                    NaN
# 14                   DX:  L TOE CONT, SUBUNGUAL HEMATOMA.
# 15                                   DX:  HAND LACERATION
# 16                                                    NaN
# 17                                                    NaN
# 18                                                    NaN
# 19                                              LAC  FACE
# 20                                                    NaN
# 21      IKE. DX LACERATION. DEEP DIRTY WOUND LEFT KNEE...
# 22                                     DX  SCALP HEMATOMA
# 23                                                    NaN
# 24                                                    NaN
# 25                RDWOOD FLOOR CRIED DX PARIETAL HEMATOMA
# 26                                        L DX TOE SPRAIN
# 27                                                    NaN
# 28                                                    NaN
# 29                    OTHER PLAYER. +DAZED. / BACK STRAIN
# ...                                                   ...
# 357697                                                NaN
# 357698                                                NaN
# 357699                                            >>CONTS
# 357700                                                NaN
# 357701                      ME. DX LOW BACK SPRAIN STRAIN
# 357702                                                NaN
# 357703                                                NaN
# 357704                                                NaN
# 357705                                                NaN
# 357706                         DX LACERATION TO RIGHT EAR
# 357707                                                NaN
# 357708                                              >>LAC
# 357709                                                NaN
# 357710                                                NaN
# 357711  FELL OFF BED ONTO THE FLOOR CRYING HIT HEAD. D...
# 357712                         BEEN LIMPING SINCE DX LIMP
# 357713                                                NaN
# 357714                                          SHOULDER.
# 357715                             O R ELBOW AND WRIST PN
# 357716  IR GEL THEN PUT THE GEL IN HER MOUTH, BEGAN VO...
# 357717                                                NaN
# 357718                       STRAP A CHILD IN A STROLLER.
# 357719                                     TO BACK OF EAR
# 357720  PASSED OUT TO THE FLOOR ONTO HEAD CLOSED HEAD ...
# 357721                                                NaN
# 357722                                                NaN
# 357723                                                NaN
# 357724                                              >>LBP
# 357725                                         LACERATION
# 357726         +PAIN TO RT WRIST & FOREARM.  DX; WRIST FX
#
# [357727 rows x 19 columns]

# %%
pd.read_csv?

# %%
df_wringer = pd.read_csv("categories-cleaned.txt", names=['product_code','product_name'])
df_wringer

#df_wringer.rename(columns={'Wringer washing machines': 'product_name', '0102': 'product code'}, inplace=True)
# Out:
#      product_code                                       product_name
# 0             102                           Wringer washing machines
# 1             106            Electric clothes dryers without washers
# 2             107                 Gas clothes dryers without washers
# 3             110                              Electric heating pads
# 4             112                     Sewing machines or accessories
# 5             113                            Floor buffers or waxers
# 6             114                                     Rug shampooers
# 7             115                                    Vacuum cleaners
# 8             116                                    Electric brooms
# 9             118                                  Gas water heaters
# 10            119  Electric water heaters (excluding immersion he...
# 11            125       Water softeners or conditioners (appliances)
# 12            127                      Clothes dryers, not specified
# 13            131        Propane, LP or butane gas tanks or fittings
# 14            132                        Electric blankets or sheets
# 15            133                                Other water heaters
# 16            134                       Water heaters, not specified
# 17            136                                 Drinking fountains
# 18            137  Automatic doors or door openers (excluding gar...
# 19            138             Automatic garage doors or door openers
# 20            139                                       Incinerators
# 21            140           Washing machines, other or not specified
# 22            212                              Electric corn poppers
# 23            213                               Electric can openers
# 24            214                                        Dishwashers
# 25            215                                  Electric blenders
# 26            216  Electric counter-top ovens, broilers or toaste...
# 27            217                  Electric coffee makers or teapots
# 28            218                 Electric or battery-powered knives
# 29            219                               Electric deep fryers
# ..            ...                                                ...
# 773          5001                     Other toy weapons (projectile)
# 774          5005  Riding toys (excluding bicycles and tricycles)...
# 775          5006                                     Other toy guns
# 776          5007                         Toy weapons, not specified
# 777          5010  Crayons or chalk (excluding billiard or pool c...
# 778          5011  Book bags or back carriers (excluding baby car...
# 779          5013  Toy make-up kits or cosmetics (excluding mirrors)
# 780          5015                     Toy caps, cap toys or cap guns
# 781          5016                      Balls, other or not specified
# 782          5017                        Flying discs and boomerangs
# 783          5018                  Doll houses and other play scenes
# 784          5019  Games or game parts (excluding marbles and com...
# 785          5020  Pretend electronics, tools, housewares, and ap...
# 786          5021               Toy vehicles (excluding riding toys)
# 787          5029  Camping equipment (excl. trailers, lighting eq...
# 788          5030  Track and field (activity, apparel or equipmen...
# 789          5031     Snow boarding (activity, apparel or equipment)
# 790          5032     Roller hockey (activity, apparel or equipment)
# 791          5033    Mountain or all-terrain bicycles or accessories
# 792          5034          Softball (activity, apparel or equipment)
# 793          5035                                 Minibikes, powered
# 794          5036  Two-wheeled, powered, off-road vehicles (incl....
# 795          5037                                           Hammocks
# 796          5038  Fitness/activity tracker, personal (including ...
# 797          5040  Bicycles or accessories (excluding mountain or...
# 798          5041  Baseball (activity, apparel or equipment; excl...
# 799          5042                      Scooters/skateboards, powered
# 800          5043                            Portable swimming pools
# 801          5044                                   Utility vehicles
# 802          5555  Substance ingested or inhaled by a victim unde...
#
# [803 rows x 2 columns]

# %% [markdown]
# ## How many different categories are electric/electrical/electronic?

# %%
regex = r"^.*elec+.*$"

# %%
len([line for line in df_wringer['product_name'] if re.search(regex, line, re.IGNORECASE)])
# Out:
# 64

# %% [markdown]
# ## Join this with your injuries dataframes to give every row a text product code

# %%
df_combined = df.merge(df_wringer, left_on="prod1", right_on="product_code")

# %%
df_combined
# Out:
#         CPSC Case #   trmt_date  psu   weight stratum  
# 357705    150129032  01/11/2015   64  15.0591       V   72    2     1
# 357706    150320629  02/28/2015   95  15.7762       V   55    2     1
# 357707    151248331  12/21/2015   32   4.9655       C    6    2     1
# 357708    150119254  01/05/2015   78  97.9239       M    6    1     2
# 357709    160104560  12/09/2015    8   4.9655       C   13    1     1
# 357710    150631452  05/24/2015   41  15.0591       V    6    1     0
# 357711    151136319  11/11/2015   25  16.5650       V   29    2     2
# 357712    150612363  06/02/2015   21  15.7762       V   46    2     0
# 357713    150938753  09/14/2015   17  15.7762       V   48    1     0
# 357714    151136084  11/05/2015   41  16.5650       V   40    1     0
# 357715    150363278  03/26/2015   58  15.0591       V  202    2     0
# 357716    150513004  05/01/2015   18   5.6748       C  206    1     1
# 357717    150149239  01/12/2015   91  15.0591       V   44    1     3
# 357718    151027130  10/05/2015   38  16.5650       V   22    1     0
# 357719    151012368  09/30/2015   32   5.6748       C  221    1     1
# 357720    150313538  02/27/2015   89  74.8813       L    4    1     1
#
#        race_other  diag                        ...                          \
# 0             NaN    57                        ...
# 1             NaN    57                        ...
# 2             NaN    57                        ...
# 3             NaN    64                        ...
# 4             NaN    62                        ...
# 5             NaN    64                        ...
# 6             NaN    64                        ...
# 7             NaN    64                        ...
# 8             NaN    57                        ...
# 9             NaN    52                        ...
# 10            NaN    71                        ...
# 11            NaN    52                        ...
# 12            NaN    71                        ...
# 13            NaN    71                        ...
# 14            NaN    57                        ...
# 15            NaN    57                        ...
# 16            NaN    57                        ...
# 17            NaN    71                        ...
# 18            NaN    64                        ...
# 19            NaN    57                        ...
# 20            NaN    64                        ...
# 21            NaN    71                        ...
# 22            NaN    64                        ...
# 23            NaN    62                        ...
# 24            NaN    64                        ...
# 25        UNKNOWN    64                        ...
# 26            NaN    71                        ...
# 27       HISPANIC    71                        ...
# 28            NaN    59                        ...
# 29            NaN    55                        ...
# ...           ...   ...                        ...
# 357691        NaN    59                        ...
# 357692        NaN    59                        ...
# 357693        NaN    59                        ...
# 357694        NaN    57                        ...
# 357695        NaN    50                        ...
# 357696    UNKNOWN    64                        ...
# 357697        NaN    49                        ...
# 357698        NaN    51                        ...
# 357699        NaN    68                        ...
# 357700        NaN    49                        ...
# 357701        NaN    51                        ...
# 357702        NaN    57                        ...
# 357703        NaN    59                        ...
# 357704        NaN    51                        ...
# 357705        NaN    59                        ...
# 357706        NaN    64                        ...
# 357707        NaN    53                        ...
# 357708        NaN    56                        ...
# 357709        NaN    56                        ...
# 357710        NaN    72                        ...
# 357711        NaN    59                        ...
# 357712        NaN    71                        ...
# 357713        NaN    57                        ...
# 357714        NaN    57                        ...
# 357715        NaN    53                        ...
# 357716        NaN    58                        ...
# 357717   HISPANIC    67                        ...
# 357718        NaN    52                        ...
# 357719        NaN    62                        ...
# 357720        NaN    51                        ...
#
#                 body_part disposition  location  fmv  prod1   prod2  \
# 0               lower arm           1         9    0   1267     NaN
# 1               lower leg           1         9    0   1267     NaN
# 2               lower arm           1         0    0   1267     NaN
# 8       17YOF COLLIDED HEADS PLAYING SOCCER GAME; ORBI...
# 9                 15YOM CONCUSSION - KNEED PLAYING SOCCER
# 10      8YOF PAIN TO R WRIST WHEN PLAYING SOCCER AND K...
# 11      13 YOM PLAYING IN A SOCCER GAME KICKED THE BAL...
# 12      10 YO F WITH R KNEE PAIN WHEN TWISTED KNEE, LE...
# 13      8YOM WAS PLAYING SOCCER WHEN HE WAS KICKED IN ...
# 14      12 YO M WITH FX TO R 5TH FINGER TRIPPED OVER A...
# 15      13YOM WAS PLAYING SOCCER WHEN HE FELL ONTO HIS...
# 16      13 YOM PLAYING SOCCER WAS RUNNING STOPPED TO G...
# 17      14YOF AT SOCCER PRACTICE & RAN MORE THAN USUAL...
# 18                15YOF WITH SPRAINED WRIST DURING SOCCER
# 19      DX CUBOID FX RT FOOT 29YOM PATIENT WHILE PLAYI...
# 20      ANKLE SPRAIN 14 YO M HURT ANKLE PLAYING SOCCER...
# 21      7YOM FELL @ CAMP 2 WKS AGO PLAYING SOCCER.  C/...
# 22      8  YOF   FELL   WHILE  PLAYING  SOCCER  SUSTAI...
# 23      17 YOM SUSTAINED A TRAUMATIC BRAIN INJURY AFTE...
# 24      16YOF INJURED LT KNEE WHILE PLAYING SOCCER.  D...
# 25      13 YOM AT SOCCER PRACTICE, TRIPPED OVER RUT IN...
# 26      17YOM WAS PLAYING SOCCER WHEN HE DEVELOPED DIF...
# 27      12YOM WAS PLAYING SOCCER 1 DAY AGO WHEN HE WAS...
# 28      14YM PLAYING SOCCER&ACC JAMMED FINGER ON THE G...
# 29          26 YOM HAD PX WHILEPLAYING SOCCER 2 DAYS AGO.
# ...                                                   ...
# 357691  57YM ACC CUT *** ON AN ELECTRIC KNIFE SLICING ...
# 357692  61YOM CUT THUMB WITH ELECTRIC KNIFE.  LEFT THU...
# 357693  34YOM-THUMB LAC-CUT ON ELECTRIC KNIFE WHILE CU...
# 357694               30YOM FX FINGER USING SHAPER MACHINE
# 357695  73YOM PT COMPLAINING OF CUTTING HAND WITH WOOD...
# 357696  57YOM WAS TYING HIS SHOELACES ON SUNDAY, FELT ...
# 357697  28YOM WITH CHEMICAL BURN TO FACE AFTER A CAN O...
# 357698  69 YOM INJURED CHEST, ABDOMIN,BURNED USING SEA...
# 357699  23YOF POSS INGESTION OF FLUX WAS USING IN META...
# 357700  61YOM BURNED ARM WITH ROOF CLEANER DX CHEMICAL...
# 357701  32YOM WAS SPRAYING AN AEROSOL SEALANT IN AN EN...
# 357702  67YOF RUSHING INTO HER HOUSE TO TURN OFF HER S...
# 357703  36 YOF WAS RUNNING TO DISARM ALARM  SYSTEM AND...
# 357704  3 YOM W/ HX. OF AUTISM GOT HIS ARM BURNED ON P...
# 357705  72YOF WITH LACERATION TO FINGER AFTER CUTTING ...
# 357706  LUMBAR STR.  55YOF FELL AGAINST A JEWELRY BOX ...
# 357707  6 YOF 4 YR OLD SIBLING THREW A JEWELRY MUSIC B...
# 357708  6 YOM INJURED EAR, BROTHER SPRAYED MINT AEROSO...
# 357709  13YOM PUT 45 CALLIBER BULLET IN A FLARE GUN, E...
# 357710  6YOM WAS PLAYING W/ A FLARE GUN AND IT WENT OF...
# 357711  A 29YOF WAS USING CORKSCREW TO OPEN BOTTLE, HA...
# 357712  46YF SUSTAINED PW TO RT INDEX FINGER ON WINE O...
# 357713   48 YO M INJURED FINGER ON BREAD CRUSHING MACHINE
# 357714  40YOM W/FXS, LACS & PUNCTURE WOUNDS OF FINGERS...
# 357715  2 MOF HAD BABY SHAMPOO BOTTLE FALL ONTO HEAD W...
# 357716  6 MOM WAS IN A CHILD PORTABLE BATH TUB THAT WA...
# 357717  44YOM FIXING WATER HEATER AT HOME AND TOUCHED ...
# 357718  22 YR OLD MALE INTOXICATED AND FELL LBACK AND ...
# 357719  21 MOM FELL AT HOME HIT HIS HEAD ON A BRICK CH...
# 357720  4 YO M PT WAS AT *** AND TIOUCH A HOT FOOD WAR...
#
#                                                     narr2 product_code  \
# 0                                                    X IT         1267
# 1                        LE CAUSING INJURY TO DISTAL FIB.         1267
# 2                                                     NaN         1267
# 3                                         DXL KNEE SPRAIN         1267
# 4                                                   >>CHI         1267
# 5                                                >>SPRAIN         1267
# 6                                                     NaN         1267
# 7                                                     NaN         1267
# 8                                            COMPLEX RFX.         1267
# 9                                                     NaN         1267
# 10                                           / WRIST PAIN         1267
# 11                      IM IN THE HEAD/FACE DX CONCUSSION         1267
# 12                                             OCCER BALL         1267
# 13                                  FELL ON IT; KNEE PAIN         1267
# 14                                      ING A SOCCER GAME         1267
# 15               C/O FOREARM/WRIST PAIN; FOREARM FRACTURE         1267
# 16                                     DX FIBULA FRACTURE         1267
# 17                                 HE, VOMITING; MIGRAINE         1267
# 18                                                    NaN         1267
# 19      AND TRIPPING ON FIELD FELT PN AND HEARD POP TO...         1267
# 20                                                    NaN         1267
# 21      NS. SWELLING/REDNESS RT ELBOW   DX; SKIN INFEC...         1267
# 22                                    HER   RIGHT   WRIST         1267
# 23                     D WITH A SOCCER BALL DURING A GAME         1267
# 24                                                    NaN         1267
# 25                                                      .         1267
# 26      BEGAN HYPERVENTILATING/WHEEZING; RESPITORY DIS...         1267
# 27      , C/O HAND/FOREARM PAIN AND SWELLING; FOREARM ...         1267
# 28                                                  >>LAC         1267
# 29                      DX:  INTERNAL DERANGEMENT L KNEE.         1267
# ...                                                   ...          ...
# 357691                                              >>LAC          218
# 357692                                                NaN          218
# 357693                                                NaN          218
# 357694                                                NaN          808
# 357695  D FOREFINGER AMPUTATED, FINGER AMPUTATION DX F...          808
# 357696  BACK WITH PAIN & DISCOMFORT. DX - ACUTE LUMBAR...         1539
# 357697                               E DX  CHEMICAL BURN*          833
# 357698  FIRE, FIRE, NO SMOKE,NO FD. DX-BURN,CHEST ABDO...          833
# 357699   G GLOVES ABD PX FLUSHED HOT DX-CHEMICAL EXPOSURE          833
# 357700                                                NaN          833
# 357701  SUSTAINED BURNS TO FACE & ARMS. DX - 1ST & 2ND...          833
# 357714                              Bread making machines
# 357715             Baby bathtub seats or rings (not toys)
# 357716             Baby bathtub seats or rings (not toys)
# 357717  Electric water heaters (excluding immersion he...
# 357718                   Brick, stone or masonry chimneys
# 357719                   Brick, stone or masonry chimneys
# 357720                                       Food warmers
#
# [357721 rows x 21 columns]

# %% [markdown]
# ## How many different injuries involved an electric/electrical/electronic product?

# %%
regex = r"^.*elec+.*$"

# %%
len([line for line in df_combined['product_name'] if re.search(regex, line, re.IGNORECASE)])
# Out:
# 3479

# %% [markdown]
# ## Graph the most common injuries involving an electrical product

# %%
def injury():
    injuries = [line for line in df_combined['product_name'] if re.search(regex, line, re.IGNORECASE)]
    series = pd.Series(injuries)
    print(series.value_counts(ascending=True).tail().plot(kind='barh'))

# %%
# df[df.body_part != 'not recorded'].body_part.value_counts(ascending=True).plot(kind= 'barh')

# %%
injury()
# Out:
# Axes(0.125,0.125;0.775x0.755)

# %% [markdown]
# ## When people get injuries using an electrical product, what part of their body is injured?

# %%
df_combined['product_name'].str.contains(regex, na=False).value_counts()
# Out:
# False    355193
# True       2528
# Name: product_name, dtype: int64

# %%
df_combined['injury_electricity'] = df_combined['product_name'].str.contains(regex, na=False)

# %%
df_combined.head()
# Out:
#    CPSC Case #   trmt_date  psu   weight stratum  age  sex  race race_other  \
# 0    150733174  07/11/2015   38  15.7762       V    5    1     0        NaN
# 1    150821622  07/20/2015   43  83.2157       S   20    2     1        NaN
# 2    150948626  09/08/2015   37   5.6748       C   10    2     0        NaN
# 3    151029422  10/06/2015   24  97.9239       M   37    1     1        NaN
# 4    151029234  10/10/2015   21  16.5650       V   13    2     0        NaN
#
#    diag         ...         disposition location  fmv  prod1  prod2  \
# 0    57         ...                   1        9    0   1267    NaN
# 1    57         ...                   1        9    0   1267    NaN
# 2    57         ...                   1        0    0   1267    NaN
# 3    64         ...                   1        0    0   1267    NaN
# 4    62         ...                   1        9    0   1267    NaN
#
#                                                narr1  \
# 0  5 YR OLD MALE PLAYING SOCCER BLOCKING BALL AND...
# 1  L DISTAL FIB FX/20YOWF WHILE PLAYING SOCCER AT...
# 2  10 YO F TRIPPED FORWARD WHEN PLAYING SOCCER FX...
# 3  J/ 37 YOM. LT KNEE PAIN AFTER HE KICKED THE BA...
# 4  13YF H/A&VOMITINGX4 S/P GOT STRUCK TO HEAD C T...
#
#                               narr2 product_code  \
# 0                              X IT         1267
# 1  LE CAUSING INJURY TO DISTAL FIB.         1267
# 2                               NaN         1267
# 3                   DXL KNEE SPRAIN         1267
# 4                             >>CHI         1267
#
#                               product_name  injury_electricity
# 0  Soccer (activity, apparel or equipment)               False
# 1  Soccer (activity, apparel or equipment)               False
# 2  Soccer (activity, apparel or equipment)               False
# 3  Soccer (activity, apparel or equipment)               False
# 4  Soccer (activity, apparel or equipment)               False
#
# [5 rows x 22 columns]

# %%
df_electric = df_combined[df_combined.injury_electricity == True]

# %%
df_electric
# Out:
#         CPSC Case #   trmt_date  psu   weight stratum  
# 357641           NaN    51         ...                   1        1    0
# 357642           NaN    51         ...                   1        0    0
# 357643       UNKNOWN    53         ...                   1        1    0
# 357644   MULTIRACIAL    51         ...                   1        1    0
#
#         prod1   prod2                                              narr1  \
# 244928    557  4076.0  6 YO M WAS SHOWING MOM SOMETHING ON *** TRYING...
# 244929    557     NaN       40YOM WITH SPRAINED ANKLE, KICKED A COMPUTER
# 244930    557     NaN  33YOF ON AN AIRPLANE AND SHE OPENED THE OVERHE...
# 244931    557     NaN  3YM ACC GOT HIT TO THE HEAD C AN ***/TABLET BY...
# 244932    557     NaN  7 YO M WAS RUNNING TO GET AN *** AND INVERTED ...
# 244933    557     NaN  51 YOF DROPPED A LAPTOP COMPUTER ON HER FOOT, ...
# 244934    557     NaN  39YOM AT HOME C/O LEFT LOWER BACK PAIN STS STA...
# 244935    557     NaN               34 Y/O M  HIT LOWER BACK ON COMPUTER
# 244936    557     NaN  21 YOF PRESENTS WITH PAIN IN LEFT HAND AFTER A...
# 244937    557  4074.0  *48YOM,WORKING ON COMPUTER ALL NIGHT,RESTING E...
# 244938    557     NaN  3 YO FEMALE FELL INTO AN ARCADE GAME AT ***.  ...
# 244939    557     NaN  49YOF C/O HAND NUMBNESS THAT IS WORSE WHEN SHE...
# 244940    557     NaN   57 YOM WAS MOVING A LARGE COMPUTER AND CUT HAND.
# 244941    557  4074.0  68 YOF TRIPPED ON COMPUTER CORD & HIT CHEST ON...
# 244942    557     NaN                         53 YOF DROPPED *** ON TOE.
# 244943    557     NaN  23 YOF C/O PAIN LEFT FOOT AFTER COMPUTER FELL ...
# 244944    557     NaN  21YOM LAC TO R HAND ON A SHARP METAL PIECE ON ...
# 244945    557     NaN  4 YO MALE FELL AND HIT FACE ON A COMPUTER MODE...
# 244946    557     NaN  8 YOF INVERTED ANKLE WHILE PLAYING *** AND INJ...
# 244947    557     NaN  12YOM WAS STANDING ON A COMPUTER MODEM AND FEL...
# 244948    557     NaN           A 57YOF HIT HEAD ON COMPUTER, CONCUSSION
# 244949    557     NaN  24 YOF INJURED WRIST ON COMPUTER ALOT. DX-CARP...
# 244950    557     NaN  4YOM MOM NOTICED GREAT TOE SWELLING, TRIED TO ...
# 244951    557     NaN  40YOF H/O TGA S/P REPAIR, HAS PACEMAKER, PLAYI...
# 244952    557     NaN  18 MONTH OLD M PULLING *** FROM SIBLING GOT HI...
# 244953    557     NaN  15YOM PLAYING VIDEO GAMES, HAD SEIZURE;  DX SE...
# 244954    557     NaN   4YOM FELL WHEN RUNNING WITH ***;  DX LAC EYEBROW
# 244955    557     NaN  3YOF PLAYING W/ AN ***, DROPPED IT ONTO CHEST ...
# 244956    557     NaN  *8YOM,AT PIZZA PLACE RUNNING FELL FWD STRIKING...
# 244957    557     NaN  11YO M BEGAN HAVING NECK PAIN AFTER PLAYING VI...
# ...       ...     ...                                                ...
# 356793   4065     NaN  33YOF REACHED TO TURN OFF ALARAM CLOCK; FELT P...
# 356794   4065     NaN  74YOM W/FOREARM LACS. REPORTS HE FELL INTO THE...
# 356795   4065     NaN  18 YO M, PER PT BROTHER WAS SWINGING THE CORD ...
# 356796   4065     NaN  HEAD INJ/81YOWF STS THAT SHE FELL AT HOME ONE ...
# 356797   4065     NaN  DX LOW BACK PN 41YOM PATIENT WITH LOW BACK PN ...
# 356798   4065  1884.0  2 YOM CONTUSION TO HEAD AFTER  A CLOCK FELL FR...
# 356799   4065     NaN  36 YOM WAS UNPLUGGING CORD WHEN CLOCK JERKED A...
# 356800   4065  1884.0  42 YOM GOT HIT ON HIS HEAD BY A CLOCK THAT FEL...
# 356801   4065     NaN  45YOF REACHED RT ARM OVER TO TURN OFF ALARM CL...
# 357310   4066     NaN  58 YO MALE TRIPPED AND FELL GETTING OFF SCALES...
# 357311   4066     NaN  64YOM FELL ON WRIST IN NURSING HOME HELPING SO...
# 357312   4066  1807.0  78YOF WITH COMPRESSION FRACTURE TO LOW BACK AF...
# 357313   4066  1807.0  55YOF ABR KNEES - STEP ON ELECTRONIC SCALE AT ...
# 357314   4066  1807.0  CHI;ABRAS/90YOWM WAS STEPPING OFF A SCALE IN H...
# 357315   4066     NaN  CHI.  82YOM LOST BALANCE WHEN STANDING ON SCAL...
# 357316   4066     NaN  75 YOF KNEE CONTUSION, SENT FROM SNF S/P FALL,...
# 357317   4066     NaN  TRAUMA FACE 2YOF FELL ONTO GLASS BATHROOM SCAL...
# 357318   4066  1807.0  SCALP CONT.  49YOF WHILE MOVING SCALES FELL AN...
# 357498    401     NaN  3MOM HIT IN THE HEAD WHEN HIS MOTHER THREW A C...
# 357583   1739     NaN  A 68YOF STEPPED ON AN ASHTRAY, LACERATION TO FOOT
# 357635   1742     NaN  *32YOM,HOT WATER BAG APPLYING TO CHEST FOR CON...
# 357636   1742     NaN  37YF C/O LESION ON MID LOWER BACKX2WKS SINCE F...
# 357637   1742     NaN  52YOM USED A MICROWAVEABLE HEATING PAD THAT BU...
# 357638   1742   281.0  28 YO FEMALE HAD HEATING PAD SHE WAS HEATING O...
# 357639   1742     NaN  8 YOF AT SCHOOL WHEN SHE GOT THE CONTENTS FROM...
# 357640   1742     NaN  57 YOF PUT A STICKY HEATING PAD ON FOOT & LEFT...
# 357641   1742     NaN  52 YR OLD MALE PUT 2 HOT PACKS ONTO HIP AND FE...
# 357642   1742     NaN  15 YO F C/O BURN OCCURRED 1 MTH AGO W/ HOT PAC...
# 357643   1742     NaN  33 YOF WAS HELPING HUSBAND WITH AN ICE PACK WH...
# 357644   1742  1934.0  27YOM, DX W/ 2 KIDNEY STONES LAST WK, HAS BURN...
#
#                                                     narr2 product_code  \
# 244928  'S BED AND SLIPPED HITTING R SIDE OF HEAD ON W...          557
# 244929                                                NaN          557
# 244930     TOP COMPUTER FELL ONTO HEAD CLOSED HEAD INJURY          557
# 244931                                              >>LAC          557
# 244932                                                NaN          557
# 244933  *** SO SHE CAME HERE TO GET IT CHECKED DX CONT...          557
# 244934                   O DROP A LAPTOP DX LOW BACK PAIN          557
# 244935                                           LS  CONT          557
# 244936           TER ON IT AT HOME.  DX:  HAND CONTUSION.          557
# 244937  HAIR,FELL ASLEEP UKNOWNTIME,UNABLETOUSE FINGER...          557
# 244938                                               TION          557
# 244939                             ULNA NERVE IMPINGEMENT          557
# 244940                              DX:  R HAND LAC 3 CM.          557
# 244941               DX:  CHEST WALL CONT, BILAT KNEE PX.          557
# 244942                           DX:  SUBUNGUAL HEMATOMA.          557
# 244943                                               FOOT          557
# 244944                                         / HAND LAC          557
# 244945                                                NaN          557
# 244946                                       DX  FRACTURE          557
# 244947                              BACK; BACK LACERATION          557
# 244948                                                NaN          557
# 244949                                        RIGHT WRIST          557
# 244950  L, ALSO DROPPED TABLET ON FOOT, NOW INCREASED ...          557
# 244951  NE IN THE DARK IN BED AT HOME, HAD JERKING W/L...          557
# 244952                                                NaN          557
# 244953                                                NaN          557
# 244954                                                NaN          557
# 244955                                                NaN          557
# 244956                                               FACE          557
# 244957                                              OLLIS          557
# ...                                                   ...          ...
# 356793                              DX: NECK MUSCLE SPASM         4065
# 356794                 LOCK IN HALLWAY. NO LOC. ETOH 240.         4065
# 356795                             THE FACE DX FACIAL LAC         4065
# 356796  ON A GRANDFATHER CLOCK. DENIES LOC. DOES NOT R...         4065
# 356797  WENT TO SHUT OFF HIS ALARM CLOCK & HAD A ACUTE...         4065
# 356798                                             E HEAD         4065
# 356799                                      DX:  LIP LAC.         4065
# 356800                    IS EVENING. DX LACERATION SCALP         4065
# 356801                             BACK   DX: BACK STRAIN         4065
# 357310                                             PAIN B         4066
# 357311                                                NaN         4066
# 357312              R STEPPING ON A SCALE. FELL TO FLOOR.         4066
# 357313                                                NaN         4066
# 357314  E TRIPPED, FALLING BACKWARD AND STRIKING HIS H...         4066
# 357315                                                NaN         4066
# 357316  N ELECTRIC SCALE WHEN KNEE BUCKLED AND SHE FEL...         4066
# 357317                                    DX: TRAUMA FACE         4066
# 357318                                                ME.         4066
# 357498  D AND IT HIT THE BABY'S HEAD.     DX.  LAC. HEAD.          401
# 357583                                                NaN         1739
# 357635                              BURN,DX:BURN ABD WALL         1742
# 357636                                   ON>>FOLLICULITIS         1742
# 357637  BD DX:LVAD, ABD WALL PAIN AND EDEMA, SECOND DE...         1742
# 357638     X SECOND DEGREE BURNS FACE AND LEFT HAND     B         1742
# 357639  HER EYE C/O FOREIGN BODY SENSATION, PAIN WATER...         1742
# 357640                       DX:  SECOND DEG BURN R FOOT.         1742
# 357641                                      NG HIP 1%TBSA         1742
# 357642                                     T INNER BREAST         1742
# 357643       ELBOWING PT ON THE NOSE, DX: NASAL CONTUSION         1742
# 357644  USING HOT PACKS W/ BOILING HOT WATER TO RELIEV...         1742
#
#                                              product_name  injury_electricity
# 244928         Computers (equipment and electronic games)                True
# 244929         Computers (equipment and electronic games)                True
# 244930         Computers (equipment and electronic games)                True
# 244931         Computers (equipment and electronic games)                True
# 244932         Computers (equipment and electronic games)                True
# 244933         Computers (equipment and electronic games)                True
# 244934         Computers (equipment and electronic games)                True
# 244935         Computers (equipment and electronic games)                True
# 244936         Computers (equipment and electronic games)                True
# 244937         Computers (equipment and electronic games)                True
# 244938         Computers (equipment and electronic games)                True
# 244939         Computers (equipment and electronic games)                True
# 244940         Computers (equipment and electronic games)                True
# 244941         Computers (equipment and electronic games)                True
# 244942         Computers (equipment and electronic games)                True
# 244943         Computers (equipment and electronic games)                True
# 244944         Computers (equipment and electronic games)                True
# 244945         Computers (equipment and electronic games)                True
# 244946         Computers (equipment and electronic games)                True
# 244947         Computers (equipment and electronic games)                True
# 244948         Computers (equipment and electronic games)                True
# 244949         Computers (equipment and electronic games)                True
# 244950         Computers (equipment and electronic games)                True
# 244951         Computers (equipment and electronic games)                True
# 244952         Computers (equipment and electronic games)                True
# 244953         Computers (equipment and electronic games)                True
# 244954         Computers (equipment and electronic games)                True
# 244955         Computers (equipment and electronic games)                True
# 244956         Computers (equipment and electronic games)                True
# 244957         Computers (equipment and electronic games)                True
# ...                                                   ...                 ...
# 356793               Clocks, electric or battery operated                True
# 356794               Clocks, electric or battery operated                True
# 356795               Clocks, electric or battery operated                True
# 356796               Clocks, electric or battery operated                True
# 356797               Clocks, electric or battery operated                True
# 356798               Clocks, electric or battery operated                True
# 356799               Clocks, electric or battery operated                True
# 356800               Clocks, electric or battery operated                True
# 356801               Clocks, electric or battery operated                True
# 357310  Scales, electric or battery operated (excludin...                True
# 357311  Scales, electric or battery operated (excludin...                True
# 357312  Scales, electric or battery operated (excludin...                True
# 357313  Scales, electric or battery operated (excludin...                True
# 357314  Scales, electric or battery operated (excludin...                True
# 357315  Scales, electric or battery operated (excludin...                True
# 357316  Scales, electric or battery operated (excludin...                True
# 357317  Scales, electric or battery operated (excludin...                True
# 357318  Scales, electric or battery operated (excludin...                True
# 357498                            Nonelectric can openers                True
# 357583             Ashtrays, electric or battery operated                True
# 357635     Heating or cooling comfort packs (nonelectric)                True
# 357636     Heating or cooling comfort packs (nonelectric)                True
# 357637     Heating or cooling comfort packs (nonelectric)                True
# 357638     Heating or cooling comfort packs (nonelectric)                True
# 357639     Heating or cooling comfort packs (nonelectric)                True
# 357640     Heating or cooling comfort packs (nonelectric)                True
# 357641     Heating or cooling comfort packs (nonelectric)                True
# 357642     Heating or cooling comfort packs (nonelectric)                True
# 357643     Heating or cooling comfort packs (nonelectric)                True
# 357644     Heating or cooling comfort packs (nonelectric)                True
#
# [2528 rows x 22 columns]

# %%
df_electric.body_part.value_counts()
# Out:
# finger               402
# head                 279
# face                 251
# hand                 175
# lower trunk          154
# foot                 149
# upper trunk          138
# lower arm            117
# lower leg             94
# toe                   88
# mouth                 82
# all parts of body     80
# wrist                 73
# eyeball               58
# internal              57
# shoulder              54
# neck                  52
# pubic region          46
# upper leg             38
# ankle                 36
# knee                  35
# elbow                 29
# upper arm             21
# ear                   13
# Name: body_part, dtype: int64

# %% [markdown]
# ## What product is most likely to injure your mouth?

# %%
df_electric[df_electric["body_part"] == 'mouth']["product_name"].value_counts()
# Out:
# product_name                                                                           body_part
# Nonelectric razors or shavers                                                          finger               284
# Computers (equipment and electronic games)                                             head                  74
#                                                                                        face                  65
# Nonelectric razors or shavers                                                          hand                  62
#                                                                                        lower arm             54
#                                                                                        lower leg             53
# Computers (equipment and electronic games)                                             foot                  46
#                                                                                        all parts of body     44
#                                                                                        upper trunk           43
# Nonelectric razors or shavers                                                          face                  42
#                                                                                        pubic region          41
# Floor lamps or table lamps, electric (excluding halogen lamps)                         head                  38
# Christmas decorations (nonelectric)                                                    internal              31
# Computers (equipment and electronic games)                                             lower trunk           29
# Cords, electrical, other or not specified                                              head                  28
# Musical instruments, not electric or not battery operated or not specified             head                  28
# Computers (equipment and electronic games)                                             neck                  28
#                                                                                        finger                28
# Metal cookware (nonelectric; excluding pressure cookers and canners)                   hand                  27
# Nonelectric razors or shavers                                                          foot                  26
#                                                                                        lower trunk           26
# Computers (equipment and electronic games)                                             toe                   26
# Nonelectric razors or shavers                                                          upper trunk           25
# Floor lamps or table lamps, electric (excluding halogen lamps)                         face                  24
# Musical instruments, not electric or not battery operated or not specified             face                  23
# Pretend electronics, tools, housewares, and appliances                                 face                  23
# Computers (equipment and electronic games)                                             hand                  23
#                                                                                        wrist                 22
# Nonelectric razors or shavers                                                          upper leg             22
# Clocks, not electric or not battery operated or not specified                          head                  20
#                                                                                                            ...
# Musical instruments, electric or battery operated                                      lower arm              1
# Floor lamps or table lamps, electric (excluding halogen lamps)                         knee                   1
#                                                                                        shoulder               1
# Heating or cooling comfort packs (nonelectric)                                         elbow                  1
#                                                                                        eyeball                1
#                                                                                        face                   1
#                                                                                        foot                   1
# Metal cookware (nonelectric; excluding pressure cookers and canners)                   elbow                  1
#                                                                                        internal               1
#                                                                                        neck                   1
# Scales, not electric or not battery operated or not specified (excluding baby scales)  lower leg              1
# Musical instruments, electric or battery operated                                      all parts of body      1
#                                                                                        ankle                  1
#                                                                                        foot                   1
#                                                                                        toe                    1
# Nonelectric can openers                                                                head                   1
# Musical instruments, electric or battery operated                                      upper trunk            1
#                                                                                        wrist                  1
# Musical instruments, not electric or not battery operated or not specified             ankle                  1
#                                                                                        ear                    1
#                                                                                        upper arm              1
# Nonelectric blankets                                                                   ear                    1
#                                                                                        foot                   1
#                                                                                        internal               1
#                                                                                        knee                   1
#                                                                                        mouth                  1
#                                                                                        pubic region           1
#                                                                                        toe                    1
#                                                                                        upper leg              1
# Ashtrays, electric or battery operated                                                 foot                   1
# Name: body_part, Length: 305, dtype: int64

# %% [markdown]
# ## What product is most likely to injure your ears?

# %%
#Kanye West :( 

df_electric[df_electric["body_part"] == 'ear']["product_name"].value_counts()
# Out:
# Nonelectric razors or shavers                                                 7
# Musical instruments, not electric or not battery operated or not specified    1
# Nonelectric blankets                                                          1
# Christmas decorations (nonelectric)                                           1
# Computers (equipment and electronic games)                                    1
# Other electric lighting equipment                                             1
# Pretend electronics, tools, housewares, and appliances                        1
# Name: product_name, dtype: int64
